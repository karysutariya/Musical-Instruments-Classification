# %%
import numpy as np 
import matplotlib.pyplot as plt 
  
X = ['accordion', 'banjo', 'bass', 'cello', 'clarinet', 'cymbals', 'drums', 'flute', 'guitar', 'mallet', 'mandolin', 'organ', 'piano', 'saxo', 'synth', 'trombone', 'trumpet', 'ukulele', 'violin', 'voice'] #Each list would be added as a row

ConNext = [0.79056511, 0.77027773, 0.79478591, 0.79896908, 0.75109332, 0.93974807,
 0.90692669, 0.71254542, 0.95850861, 0.76023251, 0.76076827, 0.75472376,
 0.93868725, 0.82038156, 0.93650186, 0.82564873, 0.79916515, 0.77846157,
 0.85291316, 0.91739943]

attMech =  [0.80651663, 0.77403732, 0.82123316, 0.81256457, 0.75588943, 0.94639302,
 0.90843169, 0.74307349, 0.97011068, 0.78484238, 0.78466919, 0.75205769,
 0.95088506, 0.83386589, 0.95482995, 0.83282628, 0.78849129, 0.78671464,
 0.85647642, 0.95163454]

RNN =  [0.80651663, 0.77403732, 0.82123316, 0.81256457, 0.75588943, 0.94639302,
 0.90843169, 0.74307349, 0.97011068, 0.78484238, 0.78466919, 0.75205769,
 0.95088506, 0.83386589, 0.95482995, 0.83282628, 0.78849129, 0.78671464,
 0.85647642, 0.95163454]

MLP =  [0.80651663, 0.77403732, 0.82123316, 0.81256457, 0.75588943, 0.94639302,
 0.90843169, 0.74307349, 0.97011068, 0.78484238, 0.78466919, 0.75205769,
 0.95088506, 0.83386589, 0.95482995, 0.83282628, 0.78849129, 0.78671464,
 0.85647642, 0.95163454]

font = {
    'family' : 'Arial',
    'weight' : 'bold',
    'size'   : 13
    }
plt.rc('font', **font)

X_axis = np.arange(len(X))
plt.figure(figsize=(15, 8)) 
plt.bar(X_axis - 0.3, ConNext, 0.2, label = 'ConvNext')
plt.bar(X_axis - 0.1, attMech, 0.2, label = 'attMech')
plt.bar(X_axis + 0.1, ConNext, 0.2, label = 'RNN')
plt.bar(X_axis + 0.3, attMech, 0.2, label = 'MLP')

plt.xticks(X_axis, X)
plt.xlabel("Instruments")
plt.xticks(rotation=45, ha='right')
plt.legend(loc='upper left')
plt.tight_layout()
plt.savefig('images/f1Bars.eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
import numpy as np 
import matplotlib.pyplot as plt 
  
X = ['Precision', 'Recall', 'F1-scores']
ConNext = [0.94, 0.92, 0.93]
attMech =  [0.94, 0.97, 0.96]
RNN =  [0.94, 0.97, 0.96]
MLP =  [0.94, 0.97, 0.96]
  
X_axis = np.arange(len(X))
plt.figure(figsize=(10, 6)) 
plt.bar(X_axis - 0.3, ConNext, 0.2, label = 'ConvNext')
plt.bar(X_axis - 0.1, attMech, 0.2, label = 'AttMech')
plt.bar(X_axis + 0.1, RNN, 0.2, label = 'RNN')
plt.bar(X_axis + 0.3, MLP, 0.2, label = 'MLP')
  
plt.xticks(X_axis, X)
plt.xlabel("Metrics")
plt.title("Performance of models")
plt.legend(loc='lower left')
plt.tight_layout()
plt.savefig('images/models.eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
